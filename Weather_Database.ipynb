# %%
# Import the dependencies.
import pandas as pd
import numpy as np
# City codification aggregation by latitude and longitude
from citipy import citipy
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
from config import g_key
weather_api_key
# Out:
# '0d27dec57583acdef45da172b2b2fc3d'

# %%
# Create a set of random latitude and longitude combinations. Sample of 2,000
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 762

# %%
# cities

# %%
# Perform an API call with the OpenWeatherMap.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + "9c0e199f5b647020fa536335b3fbd7d6"
# url

# %%
# Get the JSON text of the 'Get' request - See the limit of request
city_weather = requests.get(url)
city_weather.json()
# Out:
# {'cod': '400', 'message': 'Nothing to geocode'}

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Part 1 END
# Loop through all the cities in our list.
for i in range(len(cities)):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    
    # Loop through all the cities in the list.
for i, city in enumerate(cities):
#END part 2

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# END part 3
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_describe = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_describe})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 16 | kamenskoye
# City not found. Skipping...
# Processing Record 2 of Set 16 | dingle
# Processing Record 3 of Set 16 | dasoguz
# Processing Record 4 of Set 16 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 16 | severo-kurilsk
# Processing Record 6 of Set 16 | lanigan
# Processing Record 7 of Set 16 | punta arenas
# Processing Record 8 of Set 16 | hithadhoo
# Processing Record 9 of Set 16 | cabo san lucas
# Processing Record 10 of Set 16 | bluff
# Processing Record 11 of Set 16 | mantua
# Processing Record 12 of Set 16 | camacha
# Processing Record 13 of Set 16 | oranjemund
# Processing Record 14 of Set 16 | tuatapere
# Processing Record 15 of Set 16 | bela
# Processing Record 16 of Set 16 | katsuura
# Processing Record 17 of Set 16 | guerrero negro
# Processing Record 18 of Set 16 | mataura
# Processing Record 19 of Set 16 | yalta
# Processing Record 20 of Set 16 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 16 | carnarvon
# Processing Record 22 of Set 16 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 16 | zhigalovo
# Processing Record 24 of Set 16 | lompoc
# Processing Record 25 of Set 16 | nanortalik
# Processing Record 26 of Set 16 | rikitea
# Processing Record 27 of Set 16 | egvekinot
# Processing Record 28 of Set 16 | butaritari
# Processing Record 29 of Set 16 | puerto ayora
# Processing Record 30 of Set 16 | cherskiy
# Processing Record 31 of Set 16 | tuktoyaktuk
# Processing Record 32 of Set 16 | petropavl
# Processing Record 33 of Set 16 | upernavik
# Processing Record 34 of Set 16 | chokurdakh
# Processing Record 35 of Set 16 | vardo
# Processing Record 36 of Set 16 | quatre cocos
# Processing Record 37 of Set 16 | vaini
# Processing Record 38 of Set 16 | hobart
# Processing Record 39 of Set 16 | new norfolk
# Processing Record 40 of Set 16 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 16 | ushuaia
# Processing Record 42 of Set 16 | armenia
# Processing Record 43 of Set 16 | boa vista
# Processing Record 44 of Set 16 | kirkuk
# Processing Record 45 of Set 16 | kaitangata
# Processing Record 46 of Set 16 | jamestown
# Processing Record 47 of Set 16 | cape coast
# Processing Record 48 of Set 16 | borzna
# Processing Record 49 of Set 16 | bambous virieux
# Processing Record 50 of Set 16 | sao joao da barra
# Processing Record 1 of Set 17 | isangel
# Processing Record 2 of Set 17 | inyonga
# Processing Record 3 of Set 17 | kapaa
# Processing Record 4 of Set 17 | plouzane
# Processing Record 5 of Set 17 | karaul
# City not found. Skipping...
# Processing Record 6 of Set 17 | east london
# Processing Record 7 of Set 17 | cape town
# Processing Record 8 of Set 17 | vila
# Processing Record 9 of Set 17 | kruisfontein
# Processing Record 10 of Set 17 | lakeville
# Processing Record 11 of Set 17 | provideniya
# Processing Record 12 of Set 17 | ossora
# Processing Record 13 of Set 17 | esperance
# Processing Record 14 of Set 17 | chuy
# Processing Record 15 of Set 17 | arraial do cabo
# Processing Record 16 of Set 17 | contamana
# Processing Record 17 of Set 17 | yerbogachen
# Processing Record 18 of Set 17 | ponta do sol
# Processing Record 19 of Set 17 | beringovskiy
# Processing Record 20 of Set 17 | chilca
# Processing Record 21 of Set 17 | atuona
# Processing Record 22 of Set 17 | atbasar
# Processing Record 23 of Set 17 | tasiilaq
# Processing Record 24 of Set 17 | saint-philippe
# Processing Record 25 of Set 17 | qaanaaq
# Processing Record 26 of Set 17 | cidreira
# Processing Record 27 of Set 17 | yellowknife
# Processing Record 28 of Set 17 | simao
# Processing Record 29 of Set 17 | graaff-reinet
# Processing Record 30 of Set 17 | pilao arcado
# City not found. Skipping...
# Processing Record 31 of Set 17 | hermanus
# Processing Record 32 of Set 17 | trelleborg
# Processing Record 33 of Set 17 | albany
# Processing Record 34 of Set 17 | strezhevoy
# Processing Record 35 of Set 17 | riacho de santana
# Processing Record 36 of Set 17 | khatanga
# Processing Record 37 of Set 17 | swift current
# Processing Record 38 of Set 17 | georgetown
# Processing Record 39 of Set 17 | dikson
# Processing Record 40 of Set 17 | bayeux
# Processing Record 41 of Set 17 | kleck
# City not found. Skipping...
# Processing Record 42 of Set 17 | minsk
# Processing Record 43 of Set 17 | port elgin
# Processing Record 44 of Set 17 | watsa
# Processing Record 45 of Set 17 | tezu
# Processing Record 46 of Set 17 | payson
# Processing Record 47 of Set 17 | hasaki
# Processing Record 48 of Set 17 | grabouw
# Processing Record 49 of Set 17 | norman wells
# Processing Record 50 of Set 17 | fortuna
# Processing Record 1 of Set 18 | gewane
# Processing Record 2 of Set 18 | tura
# Processing Record 3 of Set 18 | cockburn town
# Processing Record 4 of Set 18 | leningradskiy
# Processing Record 5 of Set 18 | codrington
# Processing Record 6 of Set 18 | yazman
# Processing Record 7 of Set 18 | castro
# Processing Record 8 of Set 18 | kupang
# Processing Record 9 of Set 18 | coahuayana
# Processing Record 10 of Set 18 | hualmay
# Processing Record 11 of Set 18 | beloha
# Processing Record 12 of Set 18 | tiksi
# Processing Record 13 of Set 18 | araouane
# Processing Record 14 of Set 18 | dalmeny
# Processing Record 15 of Set 18 | jensen beach
# Processing Record 16 of Set 18 | dzialdowo
# Processing Record 17 of Set 18 | geraldton
# Processing Record 18 of Set 18 | belaya gora
# Processing Record 19 of Set 18 | calabar
# Processing Record 20 of Set 18 | lolua
# City not found. Skipping...
# Processing Record 21 of Set 18 | yumen
# Processing Record 22 of Set 18 | traverse city
# Processing Record 23 of Set 18 | faanui
# Processing Record 24 of Set 18 | laguna
# Processing Record 25 of Set 18 | poitiers
# Processing Record 26 of Set 18 | eureka
# Processing Record 27 of Set 18 | saskylakh
# Processing Record 28 of Set 18 | mar del plata
# Processing Record 29 of Set 18 | honghu
# Processing Record 30 of Set 18 | paamiut
# Processing Record 31 of Set 18 | bathsheba
# Processing Record 32 of Set 18 | mount gambier
# Processing Record 33 of Set 18 | ranong
# Processing Record 34 of Set 18 | damaturu
# Processing Record 35 of Set 18 | tiruchchendur
# Processing Record 36 of Set 18 | port hardy
# Processing Record 37 of Set 18 | aklavik
# Processing Record 38 of Set 18 | phibun mangsahan
# Processing Record 39 of Set 18 | hikone
# Processing Record 40 of Set 18 | nishihara
# Processing Record 41 of Set 18 | gaoua
# Processing Record 42 of Set 18 | alice springs
# Processing Record 43 of Set 18 | libertador general san martin
# Processing Record 44 of Set 18 | gashua
# Processing Record 45 of Set 18 | namibe
# Processing Record 46 of Set 18 | port alfred
# Processing Record 47 of Set 18 | maloy
# Processing Record 48 of Set 18 | mehamn
# Processing Record 49 of Set 18 | salalah
# Processing Record 50 of Set 18 | kyabe
# Processing Record 1 of Set 19 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 19 | biltine
# Processing Record 3 of Set 19 | bethel
# Processing Record 4 of Set 19 | lorengau
# Processing Record 5 of Set 19 | hofn
# Processing Record 6 of Set 19 | nago
# Processing Record 7 of Set 19 | sorland
# Processing Record 8 of Set 19 | namatanai
# Processing Record 9 of Set 19 | methven
# Processing Record 10 of Set 19 | pisco
# Processing Record 11 of Set 19 | havoysund
# Processing Record 12 of Set 19 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 19 | kamiichi
# Processing Record 14 of Set 19 | temaraia
# City not found. Skipping...
# Processing Record 15 of Set 19 | kaspiyskiy
# Processing Record 16 of Set 19 | arcata
# Processing Record 17 of Set 19 | awjilah
# Processing Record 18 of Set 19 | mangaratiba
# Processing Record 19 of Set 19 | churapcha
# Processing Record 20 of Set 19 | karratha
# Processing Record 21 of Set 19 | srednekolymsk
# Processing Record 22 of Set 19 | busselton
# Processing Record 23 of Set 19 | touros
# Processing Record 24 of Set 19 | escanaba
# Processing Record 25 of Set 19 | thompson
# Processing Record 26 of Set 19 | tessalit
# Processing Record 27 of Set 19 | bulungu
# Processing Record 28 of Set 19 | saint george
# Processing Record 29 of Set 19 | asilah
# Processing Record 30 of Set 19 | saint-leu
# Processing Record 31 of Set 19 | marondera
# Processing Record 32 of Set 19 | roma
# Processing Record 33 of Set 19 | zhanatas
# City not found. Skipping...
# Processing Record 34 of Set 19 | yurga
# Processing Record 35 of Set 19 | alekseyevsk
# Processing Record 36 of Set 19 | hamilton
# Processing Record 37 of Set 19 | pangkalanbuun
# Processing Record 38 of Set 19 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 19 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 19 | avarua
# Processing Record 41 of Set 19 | chimbote
# Processing Record 42 of Set 19 | nikolskoye
# Processing Record 43 of Set 19 | sibolga
# Processing Record 44 of Set 19 | zachagansk
# City not found. Skipping...
# Processing Record 45 of Set 19 | port-gentil
# Processing Record 46 of Set 19 | washington
# Processing Record 47 of Set 19 | port elizabeth
# Processing Record 48 of Set 19 | batemans bay
# Processing Record 49 of Set 19 | villa carlos paz
# Processing Record 50 of Set 19 | ostrovnoy
# Processing Record 1 of Set 20 | saint-pierre
# Processing Record 2 of Set 20 | kodiak
# Processing Record 3 of Set 20 | madang
# Processing Record 4 of Set 20 | umm durman
# City not found. Skipping...
# Processing Record 5 of Set 20 | barrow
# Processing Record 6 of Set 20 | cayenne
# Processing Record 7 of Set 20 | la ronge
# Processing Record 8 of Set 20 | kaa-khem
# Processing Record 9 of Set 20 | stornoway
# Processing Record 10 of Set 20 | maarianhamina
# Processing Record 11 of Set 20 | longyearbyen
# Processing Record 12 of Set 20 | lakes entrance
# Processing Record 13 of Set 20 | palmer
# Processing Record 14 of Set 20 | tarakan
# Processing Record 15 of Set 20 | gorno-altaysk
# Processing Record 16 of Set 20 | conceicao da barra
# Processing Record 17 of Set 20 | port lincoln
# Processing Record 18 of Set 20 | puerto carreno
# Processing Record 19 of Set 20 | san andres
# Processing Record 20 of Set 20 | kortkeros
# Processing Record 21 of Set 20 | sibu
# Processing Record 22 of Set 20 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 20 | bayir
# Processing Record 24 of Set 20 | herat
# Processing Record 25 of Set 20 | kyra
# Processing Record 26 of Set 20 | gurupi
# Processing Record 27 of Set 20 | dunedin
# Processing Record 28 of Set 20 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 20 | hilo
# Processing Record 30 of Set 20 | nouadhibou
# Processing Record 31 of Set 20 | kirakira
# Processing Record 32 of Set 20 | denpasar
# Processing Record 33 of Set 20 | sitka
# Processing Record 34 of Set 20 | applewood
# Processing Record 35 of Set 20 | clyde river
# Processing Record 36 of Set 20 | vestmannaeyjar
# Processing Record 37 of Set 20 | lavrentiya
# Processing Record 38 of Set 20 | boras
# Processing Record 39 of Set 20 | douglas
# Processing Record 40 of Set 20 | ambulu
# Processing Record 41 of Set 20 | madulao
# Processing Record 42 of Set 20 | san patricio
# Processing Record 43 of Set 20 | bow island
# Processing Record 44 of Set 20 | sinaloa
# Processing Record 45 of Set 20 | kethely
# Processing Record 46 of Set 20 | muros
# Processing Record 47 of Set 20 | frederico westphalen
# Processing Record 48 of Set 20 | chalmette
# Processing Record 49 of Set 20 | cockburn harbour
# City not found. Skipping...
# Processing Record 50 of Set 20 | zharkent
# Processing Record 1 of Set 21 | tabiauea
# City not found. Skipping...
# Processing Record 2 of Set 21 | bredasdorp
# Processing Record 3 of Set 21 | xuddur
# Processing Record 4 of Set 21 | jerome
# Processing Record 5 of Set 21 | zorleni
# Processing Record 6 of Set 21 | tautira
# Processing Record 7 of Set 21 | lerwick
# Processing Record 8 of Set 21 | phalodi
# Processing Record 9 of Set 21 | leeuwarden
# Processing Record 10 of Set 21 | kabalo
# Processing Record 11 of Set 21 | talnakh
# Processing Record 12 of Set 21 | tahoua
# Processing Record 13 of Set 21 | concordia
# Processing Record 14 of Set 21 | mahabad
# Processing Record 15 of Set 21 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 21 | bengkulu
# Processing Record 17 of Set 21 | wynyard
# Processing Record 18 of Set 21 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 21 | tocopilla
# Processing Record 20 of Set 21 | teguldet
# Processing Record 21 of Set 21 | grand centre
# City not found. Skipping...
# Processing Record 22 of Set 21 | richards bay
# Processing Record 23 of Set 21 | akdepe
# Processing Record 24 of Set 21 | ken caryl
# Processing Record 25 of Set 21 | vila velha
# Processing Record 26 of Set 21 | ozernovskiy
# Processing Record 27 of Set 21 | maningrida
# Processing Record 28 of Set 21 | zhezkazgan
# Processing Record 29 of Set 21 | vila franca do campo
# Processing Record 30 of Set 21 | harrisburg
# Processing Record 31 of Set 21 | pevek
# Processing Record 32 of Set 21 | victoria
# Processing Record 33 of Set 21 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 21 | el monte
# Processing Record 35 of Set 21 | anar darreh
# City not found. Skipping...
# Processing Record 36 of Set 21 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 21 | iqaluit
# Processing Record 38 of Set 21 | new cumnock
# Processing Record 39 of Set 21 | obo
# Processing Record 40 of Set 21 | grindavik
# Processing Record 41 of Set 21 | noumea
# Processing Record 42 of Set 21 | seoul
# Processing Record 43 of Set 21 | klyuchi
# Processing Record 44 of Set 21 | sumbawanga
# Processing Record 45 of Set 21 | airai
# Processing Record 46 of Set 21 | maragogi
# Processing Record 47 of Set 21 | omsukchan
# Processing Record 48 of Set 21 | lagoa
# Processing Record 49 of Set 21 | jishou
# Processing Record 50 of Set 21 | gushikawa
# Processing Record 1 of Set 22 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 22 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 22 | torbay
# Processing Record 4 of Set 22 | dali
# Processing Record 5 of Set 22 | buraydah
# Processing Record 6 of Set 22 | zarubino
# Processing Record 7 of Set 22 | huarmey
# Processing Record 8 of Set 22 | lafiagi
# Processing Record 9 of Set 22 | le vauclin
# Processing Record 10 of Set 22 | porto novo
# Processing Record 11 of Set 22 | khakhea
# Processing Record 12 of Set 22 | andenes
# Processing Record 13 of Set 22 | smolenka
# Processing Record 14 of Set 22 | komsomolskiy
# Processing Record 15 of Set 22 | wulanhaote
# City not found. Skipping...
# Processing Record 16 of Set 22 | san quintin
# Processing Record 17 of Set 22 | padang
# Processing Record 18 of Set 22 | terney
# Processing Record 19 of Set 22 | kavieng
# Processing Record 20 of Set 22 | parlakimidi
# Processing Record 21 of Set 22 | port hawkesbury
# Processing Record 22 of Set 22 | raudeberg
# Processing Record 23 of Set 22 | saint-francois
# Processing Record 24 of Set 22 | senador jose porfirio
# Processing Record 25 of Set 22 | bilma
# Processing Record 26 of Set 22 | pedernales
# Processing Record 27 of Set 22 | portland
# Processing Record 28 of Set 22 | forestville
# Processing Record 29 of Set 22 | sennoy
# Processing Record 30 of Set 22 | bara
# Processing Record 31 of Set 22 | narsaq
# Processing Record 32 of Set 22 | saint-augustin
# Processing Record 33 of Set 22 | ahipara
# Processing Record 34 of Set 22 | krasnyy chikoy
# Processing Record 35 of Set 22 | sao jose da coroa grande
# Processing Record 36 of Set 22 | san pedro
# Processing Record 37 of Set 22 | vesyegonsk
# Processing Record 38 of Set 22 | codo
# Processing Record 39 of Set 22 | san rafael
# Processing Record 40 of Set 22 | gobabis
# Processing Record 41 of Set 22 | sisimiut
# Processing Record 42 of Set 22 | candolim
# Processing Record 43 of Set 22 | caravelas
# Processing Record 44 of Set 22 | chapais
# Processing Record 45 of Set 22 | verkhnyaya inta
# Processing Record 46 of Set 22 | young
# Processing Record 47 of Set 22 | alofi
# Processing Record 48 of Set 22 | mumford
# Processing Record 49 of Set 22 | itarema
# Processing Record 50 of Set 22 | wahran
# City not found. Skipping...
# Processing Record 1 of Set 23 | saint anthony
# Processing Record 2 of Set 23 | naze
# Processing Record 3 of Set 23 | parabel
# Processing Record 4 of Set 23 | burnie
# Processing Record 5 of Set 23 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 23 | roebourne
# Processing Record 7 of Set 23 | sonkovo
# Processing Record 8 of Set 23 | ushtobe
# Processing Record 9 of Set 23 | bandarbeyla
# Processing Record 10 of Set 23 | abalak
# Processing Record 11 of Set 23 | yeppoon
# Processing Record 12 of Set 23 | tshikapa
# Processing Record 13 of Set 23 | kahului
# Processing Record 14 of Set 23 | baykit
# Processing Record 15 of Set 23 | kaifeng
# Processing Record 16 of Set 23 | berlevag
# Processing Record 17 of Set 23 | mayo
# Processing Record 18 of Set 23 | turukhansk
# Processing Record 19 of Set 23 | hun
# Processing Record 20 of Set 23 | florianopolis
# Processing Record 21 of Set 23 | waitati
# Processing Record 22 of Set 23 | ihosy
# Processing Record 23 of Set 23 | ahuimanu
# Processing Record 24 of Set 23 | bondo
# Processing Record 25 of Set 23 | kattivakkam
# Processing Record 26 of Set 23 | erenhot
# Processing Record 27 of Set 23 | klaksvik
# Processing Record 28 of Set 23 | chuzhou
# Processing Record 29 of Set 23 | marawi
# Processing Record 30 of Set 23 | reconquista
# Processing Record 31 of Set 23 | roald
# Processing Record 32 of Set 23 | boueni
# Processing Record 33 of Set 23 | mehran
# Processing Record 34 of Set 23 | bozeman
# Processing Record 35 of Set 23 | ferrol
# Processing Record 36 of Set 23 | road town
# Processing Record 37 of Set 23 | nara
# Processing Record 38 of Set 23 | dongsheng
# Processing Record 39 of Set 23 | monrovia
# Processing Record 40 of Set 23 | sherman
# Processing Record 41 of Set 23 | mineros
# Processing Record 42 of Set 23 | san juan
# Processing Record 43 of Set 23 | ancud
# Processing Record 44 of Set 23 | sorvag
# City not found. Skipping...
# Processing Record 45 of Set 23 | mashhad
# Processing Record 46 of Set 23 | sobolevo
# Processing Record 47 of Set 23 | waipawa
# Processing Record 48 of Set 23 | port macquarie
# Processing Record 49 of Set 23 | uspenka
# Processing Record 50 of Set 23 | axim
# Processing Record 1 of Set 24 | labuhan
# Processing Record 2 of Set 24 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 24 | karpogory
# Processing Record 4 of Set 24 | satitoa
# City not found. Skipping...
# Processing Record 5 of Set 24 | umm lajj
# Processing Record 6 of Set 24 | waingapu
# Processing Record 7 of Set 24 | ishigaki
# Processing Record 8 of Set 24 | morro bay
# Processing Record 9 of Set 24 | randolph
# Processing Record 10 of Set 24 | ngunguru
# Processing Record 11 of Set 24 | uyuni
# Processing Record 12 of Set 24 | cheuskiny
# City not found. Skipping...
# Processing Record 13 of Set 24 | poya
# Processing Record 14 of Set 24 | kandry
# Processing Record 15 of Set 24 | haines junction
# Processing Record 16 of Set 24 | lovozero
# Processing Record 17 of Set 24 | luderitz
# Processing Record 18 of Set 24 | zaoyang
# Processing Record 19 of Set 24 | port augusta
# Processing Record 20 of Set 24 | valparaiso
# Processing Record 21 of Set 24 | minna
# Processing Record 22 of Set 24 | serowe
# Processing Record 23 of Set 24 | nyamuswa
# Processing Record 24 of Set 24 | candelaria
# Processing Record 25 of Set 24 | ambon
# Processing Record 26 of Set 24 | mutare
# Processing Record 27 of Set 24 | acandi
# Processing Record 28 of Set 24 | buala
# Processing Record 29 of Set 24 | katangli
# Processing Record 30 of Set 24 | faya
# Processing Record 31 of Set 24 | te anau
# Processing Record 32 of Set 24 | ponta delgada
# Processing Record 33 of Set 24 | kinkala
# Processing Record 34 of Set 24 | polovinnoye
# Processing Record 35 of Set 24 | pochutla
# Processing Record 36 of Set 24 | saldanha
# Processing Record 37 of Set 24 | terenga
# City not found. Skipping...
# Processing Record 38 of Set 24 | goure
# Processing Record 39 of Set 24 | thunder bay
# Processing Record 40 of Set 24 | bonavista
# Processing Record 41 of Set 24 | zhigansk
# Processing Record 42 of Set 24 | tilichiki
# Processing Record 43 of Set 24 | nelson bay
# Processing Record 44 of Set 24 | drumheller
# Processing Record 45 of Set 24 | uetendorf
# Processing Record 46 of Set 24 | pingliang
# Processing Record 47 of Set 24 | la libertad
# Processing Record 48 of Set 24 | kroya
# Processing Record 49 of Set 24 | zhengjiatun
# Processing Record 50 of Set 24 | ahrensburg
# Processing Record 1 of Set 25 | hervey bay
# Processing Record 2 of Set 25 | tarut
# Processing Record 3 of Set 25 | nova vicosa
# Processing Record 4 of Set 25 | aykhal
# Processing Record 5 of Set 25 | esmeraldas
# Processing Record 6 of Set 25 | saint-joseph
# Processing Record 7 of Set 25 | praia da vitoria
# Processing Record 8 of Set 25 | ust-nera
# Processing Record 9 of Set 25 | ngukurr
# City not found. Skipping...
# Processing Record 10 of Set 25 | ilulissat
# Processing Record 11 of Set 25 | rybnaya sloboda
# Processing Record 12 of Set 25 | havelock
# Processing Record 13 of Set 25 | murray bridge
# Processing Record 14 of Set 25 | morris
# Processing Record 15 of Set 25 | yar-sale
# Processing Record 16 of Set 25 | santa maria del oro
# Processing Record 17 of Set 25 | samarai
# Processing Record 18 of Set 25 | krasnoshchekovo
# Processing Record 19 of Set 25 | ruidoso
# Processing Record 20 of Set 25 | port blair
# Processing Record 21 of Set 25 | mozarlandia
# Processing Record 22 of Set 25 | nynashamn
# Processing Record 23 of Set 25 | shelburne
# Processing Record 24 of Set 25 | saint-georges
# Processing Record 25 of Set 25 | scarborough
# Processing Record 26 of Set 25 | kieta
# Processing Record 27 of Set 25 | peachland
# Processing Record 28 of Set 25 | leshukonskoye
# Processing Record 29 of Set 25 | miri
# Processing Record 30 of Set 25 | ribeira grande
# Processing Record 31 of Set 25 | lebu
# Processing Record 32 of Set 25 | virginia beach
# Processing Record 33 of Set 25 | ratnagiri
# Processing Record 34 of Set 25 | viligili
# City not found. Skipping...
# Processing Record 35 of Set 25 | makakilo city
# Processing Record 36 of Set 25 | joshimath
# Processing Record 37 of Set 25 | adrar
# Processing Record 38 of Set 25 | loding
# Processing Record 39 of Set 25 | astoria
# Processing Record 40 of Set 25 | palauig
# Processing Record 41 of Set 25 | tadine
# Processing Record 42 of Set 25 | wattegama
# Processing Record 43 of Set 25 | rolim de moura
# City not found. Skipping...
# Processing Record 44 of Set 25 | nioro
# Processing Record 45 of Set 25 | buriti dos lopes
# Processing Record 46 of Set 25 | rungata
# City not found. Skipping...
# Processing Record 47 of Set 25 | mwense
# Processing Record 48 of Set 25 | hobyo
# Processing Record 49 of Set 25 | lira
# Processing Record 50 of Set 25 | henties bay
# Processing Record 1 of Set 26 | palana
# Processing Record 2 of Set 26 | thurso
# Processing Record 3 of Set 26 | pacific grove
# Processing Record 4 of Set 26 | rancho palos verdes
# Processing Record 5 of Set 26 | port moresby
# Processing Record 6 of Set 26 | maniitsoq
# Processing Record 7 of Set 26 | fairbanks
# Processing Record 8 of Set 26 | northam
# Processing Record 9 of Set 26 | mount isa
# Processing Record 10 of Set 26 | mergui
# City not found. Skipping...
# Processing Record 11 of Set 26 | owando
# Processing Record 12 of Set 26 | korla
# Processing Record 13 of Set 26 | jumla
# Processing Record 14 of Set 26 | souillac
# Processing Record 15 of Set 26 | mudgee
# Processing Record 16 of Set 26 | hammerfest
# Processing Record 17 of Set 26 | ballina
# Processing Record 18 of Set 26 | udachnyy
# Processing Record 19 of Set 26 | fukue
# Processing Record 20 of Set 26 | azimur
# City not found. Skipping...
# Processing Record 21 of Set 26 | aberdeen
# Processing Record 22 of Set 26 | champerico
# Processing Record 23 of Set 26 | belogorsk
# Processing Record 24 of Set 26 | dauriya
# Processing Record 25 of Set 26 | chernyshevskiy
# Processing Record 26 of Set 26 | artigas
# Processing Record 27 of Set 26 | doha
# Processing Record 28 of Set 26 | mujiayingzi
# Processing Record 29 of Set 26 | montepuez
# Processing Record 30 of Set 26 | lethem
# Processing Record 31 of Set 26 | maldonado
# Processing Record 32 of Set 26 | bonthe
# Processing Record 33 of Set 26 | ardakan
# Processing Record 34 of Set 26 | voznesenye
# Processing Record 35 of Set 26 | wichita falls
# Processing Record 36 of Set 26 | hambantota
# Processing Record 37 of Set 26 | sao filipe
# Processing Record 38 of Set 26 | ilawe
# Processing Record 39 of Set 26 | muyezerskiy
# Processing Record 40 of Set 26 | lensk
# Processing Record 41 of Set 26 | galveston
# Processing Record 42 of Set 26 | bargal
# City not found. Skipping...
# Processing Record 43 of Set 26 | sergach
# Processing Record 44 of Set 26 | filadelfia
# Processing Record 45 of Set 26 | north myrtle beach
# Processing Record 46 of Set 26 | san cristobal
# Processing Record 47 of Set 26 | qaqortoq
# Processing Record 48 of Set 26 | constitucion
# Processing Record 49 of Set 26 | poso
# Processing Record 50 of Set 26 | half moon bay
# Processing Record 1 of Set 27 | chuncheng
# Processing Record 2 of Set 27 | shingu
# Processing Record 3 of Set 27 | prieska
# Processing Record 4 of Set 27 | kenai
# Processing Record 5 of Set 27 | lianzhou
# Processing Record 6 of Set 27 | ilhabela
# Processing Record 7 of Set 27 | brae
# Processing Record 8 of Set 27 | ayagoz
# Processing Record 9 of Set 27 | tabas
# Processing Record 10 of Set 27 | lima
# Processing Record 11 of Set 27 | lata
# Processing Record 12 of Set 27 | muroto
# Processing Record 13 of Set 27 | sinnamary
# Processing Record 14 of Set 27 | salinopolis
# Processing Record 15 of Set 27 | gerash
# Processing Record 16 of Set 27 | sao luis
# Processing Record 17 of Set 27 | kuito
# Processing Record 18 of Set 27 | kandrian
# Processing Record 19 of Set 27 | yuxia
# Processing Record 20 of Set 27 | ladario
# Processing Record 21 of Set 27 | flinders
# Processing Record 22 of Set 27 | kamaishi
# Processing Record 23 of Set 27 | atar
# Processing Record 24 of Set 27 | soavinandriana
# Processing Record 25 of Set 27 | margate
# Processing Record 26 of Set 27 | mahebourg
# Processing Record 27 of Set 27 | okha
# Processing Record 28 of Set 27 | bilibino
# Processing Record 29 of Set 27 | abu samrah
# Processing Record 30 of Set 27 | paris
# Processing Record 31 of Set 27 | bandipur
# Processing Record 32 of Set 27 | dibaya
# City not found. Skipping...
# Processing Record 33 of Set 27 | xiuyan
# Processing Record 34 of Set 27 | san vicente
# Processing Record 35 of Set 27 | lamar
# Processing Record 36 of Set 27 | imbituba
# Processing Record 37 of Set 27 | mugur-aksy
# Processing Record 38 of Set 27 | vung tau
# Processing Record 39 of Set 27 | mezen
# Processing Record 40 of Set 27 | red bluff
# Processing Record 41 of Set 27 | istok
# Processing Record 42 of Set 27 | tatawin
# Processing Record 43 of Set 27 | kassala
# Processing Record 44 of Set 27 | taoudenni
# Processing Record 45 of Set 27 | kautokeino
# Processing Record 46 of Set 27 | pemangkat
# Processing Record 47 of Set 27 | itoman
# Processing Record 48 of Set 27 | bourg-en-bresse
# Processing Record 49 of Set 27 | maxixe
# Processing Record 50 of Set 27 | varhaug
# Processing Record 1 of Set 28 | kasongo
# Processing Record 2 of Set 28 | yatou
# Processing Record 3 of Set 28 | golyshmanovo
# Processing Record 4 of Set 28 | emerald
# Processing Record 5 of Set 28 | lazaro cardenas
# Processing Record 6 of Set 28 | rincon de la victoria
# Processing Record 7 of Set 28 | sistranda
# Processing Record 8 of Set 28 | villagarzon
# Processing Record 9 of Set 28 | flin flon
# Processing Record 10 of Set 28 | zhangye
# Processing Record 11 of Set 28 | whitehorse
# Processing Record 12 of Set 28 | bubaque
# Processing Record 13 of Set 28 | angra
# City not found. Skipping...
# Processing Record 14 of Set 28 | brasileia
# Processing Record 15 of Set 28 | harper
# Processing Record 16 of Set 28 | belmonte
# Processing Record 17 of Set 28 | nyagan
# Processing Record 18 of Set 28 | deputatskiy
# Processing Record 19 of Set 28 | birjand
# Processing Record 20 of Set 28 | tahe
# Processing Record 21 of Set 28 | miandrivazo
# Processing Record 22 of Set 28 | pincher creek
# Processing Record 23 of Set 28 | barcelona
# Processing Record 24 of Set 28 | olinda
# Processing Record 25 of Set 28 | merta
# Processing Record 26 of Set 28 | belyy yar
# Processing Record 27 of Set 28 | libreville
# Processing Record 28 of Set 28 | altay
# Processing Record 29 of Set 28 | vila do maio
# Processing Record 30 of Set 28 | lahad datu
# Processing Record 31 of Set 28 | villa rica
# Processing Record 32 of Set 28 | la argentina
# Processing Record 33 of Set 28 | maceio
# Processing Record 34 of Set 28 | launceston
# Processing Record 35 of Set 28 | panzhihua
# Processing Record 36 of Set 28 | canto do buriti
# Processing Record 37 of Set 28 | kidal
# Processing Record 38 of Set 28 | pedana
# Processing Record 39 of Set 28 | santa cruz
# Processing Record 40 of Set 28 | conceicao do araguaia
# Processing Record 41 of Set 28 | mosquera
# Processing Record 42 of Set 28 | north las vegas
# Processing Record 43 of Set 28 | tam ky
# Processing Record 44 of Set 28 | nagorsk
# Processing Record 45 of Set 28 | santa fe
# Processing Record 46 of Set 28 | the valley
# Processing Record 47 of Set 28 | san jeronimo
# Processing Record 48 of Set 28 | qandala
# Processing Record 49 of Set 28 | piacabucu
# Processing Record 50 of Set 28 | rabat
# Processing Record 1 of Set 29 | eyl
# Processing Record 2 of Set 29 | coihaique
# Processing Record 3 of Set 29 | casablanca
# Processing Record 4 of Set 29 | victoria point
# Processing Record 5 of Set 29 | vao
# Processing Record 6 of Set 29 | vangaindrano
# Processing Record 7 of Set 29 | artyk
# City not found. Skipping...
# Processing Record 8 of Set 29 | ongandjera
# Processing Record 9 of Set 29 | dicabisagan
# Processing Record 10 of Set 29 | sola
# Processing Record 11 of Set 29 | mayumba
# Processing Record 12 of Set 29 | pangnirtung
# Processing Record 13 of Set 29 | netrakona
# Processing Record 14 of Set 29 | tigil
# Processing Record 15 of Set 29 | danane
# Processing Record 16 of Set 29 | plettenberg bay
# Processing Record 17 of Set 29 | crailsheim
# Processing Record 18 of Set 29 | arman
# Processing Record 19 of Set 29 | alanya
# Processing Record 20 of Set 29 | zatoka
# Processing Record 21 of Set 29 | general pico
# Processing Record 22 of Set 29 | dudinka
# Processing Record 23 of Set 29 | kalmunai
# Processing Record 24 of Set 29 | houma
# Processing Record 25 of Set 29 | orsk
# Processing Record 26 of Set 29 | norsup
# Processing Record 27 of Set 29 | oriximina
# Processing Record 28 of Set 29 | suoyarvi
# Processing Record 29 of Set 29 | honningsvag
# Processing Record 30 of Set 29 | rio grande
# Processing Record 31 of Set 29 | winsum
# Processing Record 32 of Set 29 | natal
# Processing Record 33 of Set 29 | port keats
# Processing Record 34 of Set 29 | sur
# Processing Record 35 of Set 29 | sidi ali
# Processing Record 36 of Set 29 | salinas
# Processing Record 37 of Set 29 | prince george
# Processing Record 38 of Set 29 | aasiaat
# Processing Record 39 of Set 29 | camacupa
# Processing Record 40 of Set 29 | marzuq
# Processing Record 41 of Set 29 | semnan
# Processing Record 42 of Set 29 | tombouctou
# Processing Record 43 of Set 29 | steamboat springs
# Processing Record 44 of Set 29 | uppsala
# Processing Record 45 of Set 29 | niigata
# Processing Record 46 of Set 29 | bulawayo
# Processing Record 47 of Set 29 | loiza
# Processing Record 48 of Set 29 | tsienyane
# City not found. Skipping...
# Processing Record 49 of Set 29 | luanda
# Processing Record 50 of Set 29 | mto wa mbu
# Processing Record 1 of Set 30 | tshane
# Processing Record 2 of Set 30 | hatillo
# Processing Record 3 of Set 30 | grand gaube
# Processing Record 4 of Set 30 | antalaha
# Processing Record 5 of Set 30 | kargasok
# Processing Record 6 of Set 30 | bardiyah
# Processing Record 7 of Set 30 | athabasca
# Processing Record 8 of Set 30 | nizhneangarsk
# Processing Record 9 of Set 30 | ayios matthaios
# City not found. Skipping...
# Processing Record 10 of Set 30 | tomohon
# Processing Record 11 of Set 30 | muisne
# Processing Record 12 of Set 30 | cairns
# Processing Record 13 of Set 30 | maghama
# City not found. Skipping...
# Processing Record 14 of Set 30 | nianzishan
# Processing Record 15 of Set 30 | sokoto
# Processing Record 16 of Set 30 | goderich
# Processing Record 17 of Set 30 | derzhavinsk
# Processing Record 18 of Set 30 | mercedes
# Processing Record 19 of Set 30 | lubao
# Processing Record 20 of Set 30 | karamea
# City not found. Skipping...
# Processing Record 21 of Set 30 | talaya
# Processing Record 22 of Set 30 | ekibastuz
# Processing Record 23 of Set 30 | cubarral
# Processing Record 24 of Set 30 | general roca
# Processing Record 25 of Set 30 | tecoanapa
# Processing Record 26 of Set 30 | westport
# Processing Record 27 of Set 30 | ouadda
# Processing Record 28 of Set 30 | kismayo
# Processing Record 29 of Set 30 | lodja
# Processing Record 30 of Set 30 | taree
# Processing Record 31 of Set 30 | prince rupert
# Processing Record 32 of Set 30 | sinjar
# Processing Record 33 of Set 30 | jalpan
# Processing Record 34 of Set 30 | zhanaozen
# Processing Record 35 of Set 30 | tasbuget
# City not found. Skipping...
# Processing Record 36 of Set 30 | lufilufi
# Processing Record 37 of Set 30 | palanpur
# Processing Record 38 of Set 30 | sarankhola
# Processing Record 39 of Set 30 | rosarito
# Processing Record 40 of Set 30 | isla mujeres
# Processing Record 41 of Set 30 | conceicao do rio verde
# Processing Record 42 of Set 30 | santa vitoria do palmar
# Processing Record 43 of Set 30 | tawau
# Processing Record 44 of Set 30 | port hedland
# Processing Record 45 of Set 30 | saint-pacome
# City not found. Skipping...
# Processing Record 46 of Set 30 | alausi
# Processing Record 47 of Set 30 | wadi maliz
# Processing Record 48 of Set 30 | teahupoo
# Processing Record 49 of Set 30 | najran
# Processing Record 50 of Set 30 | jaguaruna
# Processing Record 1 of Set 31 | gzhatsk
# City not found. Skipping...
# Processing Record 2 of Set 31 | khonuu
# City not found. Skipping...
# Processing Record 3 of Set 31 | wewak
# Processing Record 4 of Set 31 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 31 | bokspits
# City not found. Skipping...
# Processing Record 6 of Set 31 | shawnee
# Processing Record 7 of Set 31 | robore
# Processing Record 8 of Set 31 | uchiza
# Processing Record 9 of Set 31 | redmond
# Processing Record 10 of Set 31 | luganville
# Processing Record 11 of Set 31 | maraa
# Processing Record 12 of Set 31 | labutta
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Dingle  10.9995  122.6711     80.24        83          89
# 1         Dasoguz  41.8363   59.9666     32.00        86         100
# 2  Severo-Kurilsk  50.6789  156.1250     12.60        86          71
# 3         Lanigan  51.8501 -105.0344     -0.40        78         100
# 4    Punta Arenas -53.1500  -70.9167     50.00        62          20
# 5       Hithadhoo  -0.6000   73.0833     82.08        77         100
# 6  Cabo San Lucas  22.8909 -109.9124     78.80        29          40
# 7           Bluff -46.6000  168.3333     58.41        67         100
# 8          Mantua  45.1667   10.7833     46.00        95          93
# 9         Camacha  33.0833  -16.3333     55.40        71          75
#
#    Wind Speed Country Current Description
# 0       13.67      PH     overcast clouds
# 1        6.91      TM     overcast clouds
# 2       11.16      RU       broken clouds
# 3        8.05      CA     overcast clouds
# 4       19.57      CL          few clouds
# 5       11.12      MV     overcast clouds
# 6        8.97      MX    scattered clouds
# 7        9.19      NZ     overcast clouds
# 8        1.99      IT     overcast clouds
# 9       14.97      PT       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
